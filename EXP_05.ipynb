# %% [markdown]
# <a href="https://colab.research.google.com/github/444-Mayavathi/Mayaraj-/blob/main/EXP_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
para = """India’s culture is diverse and ancient, shaped by many religions, languages, and traditions. It is known for colorful festivals, strong family values, and rich art, music, and cuisine."""

# %%
sentence = sent_tokenize(para)

# %%
sentence
# Out:
# ['India’s culture is diverse and ancient, shaped by many religions, languages, and traditions.',
#  'It is known for colorful festivals, strong family values, and rich art, music, and cuisine.']

# %%
sentence
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stemmer = PorterStemmer()

# %%
for i in range(len(sentence)):
  words = word_tokenize(sentence[i])
  words = [stemmer.stem(word) for word in words]
  sentence[i] = ' '.join(words)

# %%
sentence
# Out:
# ['india ’ s cultur is divers and ancient , shape by mani religion , languag , and tradit .',
#  'it is known for color festiv , strong famili valu , and rich art , music , and cuisin .']

# %%
from nltk.stem import WordNetLemmatizer

# %%
para1 = """India’s culture is diverse and ancient, shaped by many religions, languages, and traditions. It is known for colorful festivals, strong family values, and rich art, music, and cuisine."""

# %%
sentence1 = nltk.sent_tokenize(para1)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
for i in range(len(sentence1)):
  word = nltk.word_tokenize(sentence[i])
  newwords = [lemmatizer.lemmatize(word) for word in words]
  sentence1[i] = ' '.join(newwords)

# %%
sentence
# Out:
# ['india ’ s cultur is divers and ancient , shape by mani religion , languag , and tradit .',
#  'it is known for color festiv , strong famili valu , and rich art , music , and cuisin .']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
para3 = """India’s culture is diverse and ancient, shaped by many religions, languages, and traditions. It is known for colorful festivals, strong family values, and rich art, music, and cuisine."""

# %%
word = nltk.word_tokenize(para3)

# %%
tag_word = nltk.pos_tag(word)

# %%
tag_word
# Out:
# [('India', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('culture', 'NN'),
#  ('is', 'VBZ'),
#  ('diverse', 'JJ'),
#  ('and', 'CC'),
#  ('ancient', 'JJ'),
#  (',', ','),
#  ('shaped', 'VBN'),
#  ('by', 'IN'),
#  ('many', 'JJ'),
#  ('religions', 'NNS'),
#  (',', ','),
#  ('languages', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('traditions', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('colorful', 'JJ'),
#  ('festivals', 'NNS'),
#  (',', ','),
#  ('strong', 'JJ'),
#  ('family', 'NN'),
#  ('values', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('rich', 'JJ'),
#  ('art', 'NN'),
#  (',', ','),
#  ('music', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('cuisine', 'NN'),
#  ('.', '.')]

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
named_Ent = nltk.ne_chunk(tag_word)

# %%
named_Ent
# Out:
# Tree('S', [Tree('GPE', [('India', 'NNP')]), ('’', 'NNP'), ('s', 'JJ'), ('culture', 'NN'), ('is', 'VBZ'), ('diverse', 'JJ'), ('and', 'CC'), ('ancient', 'JJ'), (',', ','), ('shaped', 'VBN'), ('by', 'IN'), ('many', 'JJ'), ('religions', 'NNS'), (',', ','), ('languages', 'NNS'), (',', ','), ('and', 'CC'), ('traditions', 'NNS'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('known', 'VBN'), ('for', 'IN'), ('colorful', 'JJ'), ('festivals', 'NNS'), (',', ','), ('strong', 'JJ'), ('family', 'NN'), ('values', 'NNS'), (',', ','), ('and', 'CC'), ('rich', 'JJ'), ('art', 'NN'), (',', ','), ('music', 'NN'), (',', ','), ('and', 'CC'), ('cuisine', 'NN'), ('.', '.')])
