# %% [markdown]
# <a href="https://colab.research.google.com/github/444-Mayavathi/Mayaraj-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fef9c7bc-3d36-405e-adad-d6364034c0b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fef9c7bc-3d36-405e-adad-d6364034c0b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
out =pd.read_csv('/content/large_sales_data (1).csv')
out
# Out:
#       OrderID                 Date   Region     Category SubCategory  Sales  \
# 0           1  2024-01-01 00:00:00     West     Clothing      Mobile   5227
# 1           2  2024-01-01 01:00:00  Central        Books       Table   9098
# 2           3  2024-01-01 02:00:00     East  Electronics      Laptop   2822
# 3           4  2024-01-01 03:00:00  Central        Books       Chair   4756
# 4           5  2024-01-01 04:00:00  Central    Furniture      Laptop   1425
# ...       ...                  ...      ...          ...         ...    ...
# 2995     2996  2024-05-04 19:00:00     West    Furniture      Novels   6513
# 2996     2997  2024-05-04 20:00:00  Central  Electronics      Laptop   7714
# 2997     2998  2024-05-04 21:00:00     East  Electronics       Pants   1345
# 2998     2999  2024-05-04 22:00:00    South     Clothing       Pants   8343
# 2999     3000  2024-05-04 23:00:00     West     Clothing       Chair    637
#
#       Profit  Quantity CustomerType  PaymentMode
# ...

# %%
with open('/content/large_sales_data (1).csv')

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3035dda5-a18d-4161-983e-fa15e81d1594" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3035dda5-a18d-4161-983e-fa15e81d1594">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
out =pd.read_csv('/content/sentimentdataset.csv')
out
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
# !pip install PyPDF2

# %%
import PyPDF2
pdf_file = open('/content/FINAL_REPORT_DP____.pdf','rb')
reader = PyPDF2.PdfReader(pdf_file)
text = ""
for page in reader.pages:
  text += page.extract_text()
  print(text)
  pdf_file.close()
# Out:
# 1  FOOD  RESCUE
# A DESIGN  PROJECT -1 (5CS1990 /  5IT1990)  REPORT
#
#
# Submitted  by
#
#
# P. Sai Deepthi  (2023BCSE07AED328)
# P. Bhanu  Prakash(2023BCSE07AED331)
# S. Meghana(2023BCSE07AED436)
# Mayavathi.  S(2023BCSE07AED444)
# In partial  fulfilment  for the award  of the degree  of
#
#
# BACHELOR  OF TECHNOLOGY
# In
# COMPUTER  SCIENCE  AND  ENGINEERING  (DATA  ANALYTICS)
#
#
#
# Under  the Supervision  of
# KUSUMA  J
#
#
#
# ALLIANCE  SCHOOL  OF ADVANCED  COMPUTING
# ALLIANCE UNIVERSITY, BENGALURU
# NOVEMBER - 2025
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3357841632.py in <cell line: 0>()
#       4 text = ""
#       5 for page in reader.pages:
# ----> 6   text += page.extract_text()
#       7   print(text)
#       8   pdf_file.close()
#
# ...
