# %% [markdown]
# <a href="https://colab.research.google.com/github/444-Mayavathi/Mayaraj-/blob/main/EXP_NO_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.neural_network import MLPClassifier

# %%
file_path = "/content/SpotifyAudioFeaturesApril2019.csv.zip"

df = pd.read_csv(file_path)

print("Dataset Shape:", df.shape)
print("Columns:")
print(df.columns)
# Out:
# Dataset Shape: (130663, 17)
# Columns:
# Index(['artist_name', 'track_id', 'track_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity'],
#       dtype='object')

# %%
features = ['danceability','energy','valence',
            'tempo','loudness','acousticness']

df = df.dropna()

X = df[features]

# %%
target_col = df.select_dtypes(include=['object']).columns[0]

print("Target Column Used:", target_col)

y = df[target_col]

# Encode target labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)
# Out:
# Target Column Used: artist_name

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

print("Training samples:", X_train.shape)
print("Testing samples:", X_test.shape)
# Out:
# Training samples: (104529, 6)
# Testing samples: (26133, 6)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model1 = MLPClassifier(
    hidden_layer_sizes=(64, 32),
    activation='relu',
    learning_rate_init=0.001,
    batch_size=32,
    max_iter=1,
    warm_start=True,
    random_state=42
)
